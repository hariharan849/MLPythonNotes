# %% [markdown]
# ***Principal Component Analysis***
#
#   rotates the datasets in a way such that rotated features are statistically uncorrelated
#
# *   Component 1 finds in the direction of maximum variance
# *   next diection is orthogonal to above direction

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_lfw_people
people = fetch_lfw_people(min_faces_per_person=20, resize=0.7)
image_shape = people.images[0].shape

fig, axes = plt.subplots(2, 5, figsize=(15, 8))
for target, image, ax in zip(people.target, people.images, axes.ravel()):
  ax.imshow(image)
  ax.set_title(people.target_names[target])

# %% [markdown]
# ***Non Negative Matrix Factorization***
#   unlike PCA, non negative values are considered

# %%
from skleran.decomposition import NMF

nmf = NMF(n_components=15, random_state=0)
